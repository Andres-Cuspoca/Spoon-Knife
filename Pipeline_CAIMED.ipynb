# %% [markdown]
# <a href="https://colab.research.google.com/github/Andres-Cuspoca/Spoon-Knife/blob/master/Pipeline_CAIMED.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.DataFrame({'f1':[10,20],'f2':[20,30]})
# Out:
#    f1  f2
# 0  10  20
# 1  20  30

# %%
pd.DataFrame({'f1':[10,20],'f2':[20,30]}, index=["a", "b"])
# Out:
#    f1  f2
# a  10  20
# b  20  30

# %% [markdown]
# Hacer un data frame

# %%
fruit_sales = pd.DataFrame({'Apples':[35, 41], 
             'Bananas':[21,34]}, 
             index=['2017 Sales', '2018 Sales'])

# %% [markdown]
# Hacer series

# %%
pd.Series(["4 cups", "1 cup", "2 large", "1 can"], index=["Flour", "Milk", "Eggs", "Spam"], name= "Dinner")

# %% [markdown]
# Leer un .CVS, el index_col trabaja dejando el indice predeterminado

# %%
reviews = pd.read_csv("../input/wine-reviews/winemag-data_first150k.csv", index_col= 0)

# %% [markdown]
# Descargar a CSV

# %%
animals.to_csv("cows_and_goats.csv")

# %% [markdown]
# Vamos a intentar realizar la tabla dinamica de caimed

# %% [markdown]
# Leer desde el drive

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4566459b-d924-4c43-bb52-4b8a20fb060b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4566459b-d924-4c43-bb52-4b8a20fb060b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
PC = pd.read_csv(io.BytesIO(uploaded['pipeCAI - Hoja 1.csv']))
# Dataset is now stored in a Pandas Dataframe

# %% [markdown]
# ya esta el documento para explorar entonces queda para explorar-

# %%
PC.head()
# Out:
#      ID Patrocinador             Corte      Especialidad Area_terapeutica  \
# 0    C1          MSD           Q2 2022       Cardiología      Metabólicas
# 1    C1          MSD           Q2 2022  Medicina interna      Metabólicas
# 2   C10       Sanofi            Q32022      Dermatología         Cutaneas
# 3  C100       Pfizer  November 1, 2022       Inmunología          Vacunas
# 4  C100       Pfizer  November 1, 2022         Pediatría          Vacunas
#
#                                            condicion  \
# 0                               Hypercholesterolemia
# 1                               Hypercholesterolemia
# 2                      Chronic spontaneous urticaria
# 3  COVID-19 Infection Booster (in collaboration w...
# 4  COVID-19 Infection Booster (in collaboration w...
#
#                         Molecula  \
# 0                        MK-0616
# 1                        MK-0616
# 2                  rilzabrutinib
# 3  BNT162b2 bivalent (BA.4/BA.5)
# ...

# %% [markdown]
# vamos a intentar hacer eso.

# %%
pd.pivot_table(PC, values="condicion", index=["Area_terapeutica", "Patrocinador"], columns=["Fase"])
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py:507: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)
# Empty DataFrame
# Columns: []
# ...

# %% [markdown]
# Pivot tables
# While pivot() provides general purpose pivoting with various data types (strings, numerics, etc.), pandas also provides pivot_table() for pivoting with aggregation of numeric data.
#
# The function pivot_table() can be used to create spreadsheet-style pivot tables. See the cookbook for some advanced strategies.
#
# It takes a number of arguments:
#
# data: a DataFrame object.
#
# values: a column or a list of columns to aggregate.
#
# index: a column, Grouper, array which has the same length as data, or list of them. Keys to group by on the pivot table index. If an array is passed, it is being used as the same manner as column values.
#
# columns: a column, Grouper, array which has the same length as data, or list of them. Keys to group by on the pivot table column. If an array is passed, it is being used as the same manner as column values.
#
# aggfunc: function to use for aggregation, defaulting to numpy.mean.

# %%
import numpy as np
from sklearn.datasets import fetch_openml

# %%
pivot = np.round(pd.pivot_table(PC, values='ID', 
                                index=["Patrocinador", 'Area_terapeutica', "Fase"], 
                                columns=['Mecanismo_accion'], 
                                aggfunc=[np.mean, np.median],
                                fill_value=0),2)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/generic.py:979: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   result = op.agg()
# /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/generic.py:979: FutureWarning: Dropping invalid columns in DataFrameGroupBy.median is deprecated. In a future version, a TypeError will be raised. Before calling .median, select only columns which should be valid for the function.
#   result = op.agg()

# %%
pivot
# Out:
# Empty DataFrame
# Columns: []
# Index: [(MSD, Cancer, Approvals), (MSD, Cancer, Approvals
#
#  Phasethree), (MSD, Cancer, Approvals
#  Phase 4), (MSD, Cancer, Approvals
#  Phaseone), (MSD, Cancer, Approvals
#  Phasethree), (MSD, Cancer, Approvals
#  Phasetwo), (MSD, Cancer, Approvals
#  Phasethree), (MSD, Cancer, Phasethree), (MSD, Cancer, Phasetwo), (MSD, Cancer, under review
#  Phasethree), (MSD, Cancer, under review
#  Phasetwo), (MSD, Cancer, under review
#  Phasethree), (MSD, Cutaneas, Approvals
#  Phaseone), (MSD, Infecciosas, Approvals
#  Phaseone), (MSD, Infecciosas, Approvals
#  Phasethree), (MSD, Infecciosas, Approvals
#  Phasetwo), (MSD, Infecciosas, Approvals
#  Phasethree), (MSD, Infecciosas, Phasethree), (MSD, Infecciosas, Phasetwo), (MSD, Infecciosas, under review
#  Phasethree), (MSD, Infecciosas, Under Review
#
# ...

# %%
print(pivot)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(MSD, Cancer, Approvals), (MSD, Cancer, Approvals
#
#  Phasethree), (MSD, Cancer, Approvals
#  Phase 4), (MSD, Cancer, Approvals
#  Phaseone), (MSD, Cancer, Approvals
#  Phasethree), (MSD, Cancer, Approvals
#  Phasetwo), (MSD, Cancer, Approvals
#  Phasethree), (MSD, Cancer, Phasethree), (MSD, Cancer, Phasetwo), (MSD, Cancer, under review
#  Phasethree), (MSD, Cancer, under review
#  Phasetwo), (MSD, Cancer, under review
#  Phasethree), (MSD, Cutaneas, Approvals
#  Phaseone), (MSD, Infecciosas, Approvals
#  Phaseone), (MSD, Infecciosas, Approvals
#  Phasethree), (MSD, Infecciosas, Approvals
#  Phasetwo), (MSD, Infecciosas, Approvals
#  Phasethree), (MSD, Infecciosas, Phasethree), (MSD, Infecciosas, Phasetwo), (MSD, Infecciosas, under review
#  Phasethree), (MSD, Infecciosas, Under Review
#
# ...

# %%
from pandas import DataFrame

# %% [markdown]
# Revsisar que columnas tiene la base de datos

# %%
PC.columns
# Out:
# Index(['ID', 'Patrocinador', 'Corte', 'Especialidad', 'Area_terapeutica',
#        'condicion', 'Molecula', 'Mecanismo_accion', 'Fase', 'Fase_Stage',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14'],
#       dtype='object')

# %%
Revisar los valores que contienen las columnas en este caso Fase

# %%
pd.unique(PC['Patrocinador'])
# Out:
# array(['MSD', 'Sanofi', 'Pfizer', 'Novartis', 'Moderna'], dtype=object)

# %% [markdown]
# aca vamos a realizar varios filtros.

# %%
PC.loc[(PC["Patrocinador"]=="Moderna") & (PC["Area_terapeutica"]=="Vacunas") ]
# Out:
#        ID Patrocinador Corte      Especialidad Area_terapeutica  \
# 127  C149      Moderna   NaN  Medicina interna          Vacunas
# 128  C149      Moderna   NaN       Inmunología          Vacunas
# 132  C150      Moderna   NaN  Medicina interna          Vacunas
# 133  C150      Moderna   NaN       Inmunología          Vacunas
# 136  C151      Moderna   NaN  Medicina interna          Vacunas
# ..    ...          ...   ...               ...              ...
# 937   C78      Moderna   NaN       Inmunología          Vacunas
# 940   C79      Moderna   NaN      Infectología          Vacunas
# 941   C79      Moderna   NaN       Inmunología          Vacunas
# 945   C80      Moderna   NaN      Infectología          Vacunas
# 946   C80      Moderna   NaN       Inmunología          Vacunas
#
#                   condicion   Molecula Mecanismo_accion        Fase  \
# 127  Vacuna contra la gripe  ARNm-1010              NaN  Phasethree
# ...
